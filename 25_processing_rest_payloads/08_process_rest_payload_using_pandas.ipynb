# %% [markdown]
# ## Process REST Payload using pandas
#
# Let us understand how to process REST Payload using Pandas Dataframe APIs.
# * We can get details about all the public repositories using `GET /repositories` from **https://api.github.com**.
# * As it is getting or reading data from external application the details are available via `GET`. We will have JSON Array as part of the Payload.
# * We can convert this JSON Array to Python `list`. Each element in the list will be of type `dict`.
# * We can apply `pandas.json_normalize` to get flattened Dataframe by passing this list of dicts.
# * Let us understand how the data in this Pandas Dataframe can be processed using appropriate Pandas APIs as per our requirements.

# %%
import requests

# %%
payload = requests.get('https://api.github.com/repositories').json()

# %%
type(payload)
# Out:
# list

# %%
payload # A list which contain dicts

# %% [markdown]
# * Now we can convert the list returned to pandas dataframe using `json_normalize`.

# %%
import pandas as pd

# %%
pd.DataFrame(payload)
# Out:
#      id                   node_id                    name  \
# 0     1      MDEwOlJlcG9zaXRvcnkx                    grit
# 1    26  MDEwOlJlcG9zaXRvcnkyNg==               merb-core
# 2    27  MDEwOlJlcG9zaXRvcnkyNw==                rubinius
# 3    28  MDEwOlJlcG9zaXRvcnkyOA==                     god
# 4    29  MDEwOlJlcG9zaXRvcnkyOQ==               jsawesome
# ..  ...                       ...                     ...
# 95  364  MDEwOlJlcG9zaXRvcnkzNjQ=      acts_as_geocodable
# 96  365  MDEwOlJlcG9zaXRvcnkzNjU=           acts_as_money
# 97  367  MDEwOlJlcG9zaXRvcnkzNjc=        calendar_builder
# 98  368  MDEwOlJlcG9zaXRvcnkzNjg=  clear_empty_attributes
# 99  369  MDEwOlJlcG9zaXRvcnkzNjk=           css_naked_day
#
#                                 full_name  private  \
# 0                            mojombo/grit    False
# 1                        wycats/merb-core    False
# 2                       rubinius/rubinius    False
# 3                             mojombo/god    False
# 4                       vanpelt/jsawesome    False
# ..                                    ...      ...
# 95      collectiveidea/acts_as_geocodable    False
# 96           collectiveidea/acts_as_money    False
# 97        collectiveidea/calendar_builder    False
# 98  collectiveidea/clear_empty_attributes    False
# 99           collectiveidea/css_naked_day    False
#
#                                                 owner  \
# 0   {'login': 'mojombo', 'id': 1, 'node_id': 'MDQ6...
# 1   {'login': 'wycats', 'id': 4, 'node_id': 'MDQ6V...
# 2   {'login': 'rubinius', 'id': 317747, 'node_id':...
# 3   {'login': 'mojombo', 'id': 1, 'node_id': 'MDQ6...
# 4   {'login': 'vanpelt', 'id': 17, 'node_id': 'MDQ...
# ..                                                ...
# 95  {'login': 'collectiveidea', 'id': 128, 'node_i...
# 96  {'login': 'collectiveidea', 'id': 128, 'node_i...
# 97  {'login': 'collectiveidea', 'id': 128, 'node_i...
# 98  {'login': 'collectiveidea', 'id': 128, 'node_i...
# 99  {'login': 'collectiveidea', 'id': 128, 'node_i...
#
#                                              html_url  \
# 0                     https://github.com/mojombo/grit
# 1                 https://github.com/wycats/merb-core
# 2                https://github.com/rubinius/rubinius
# 3                      https://github.com/mojombo/god
# 4                https://github.com/vanpelt/jsawesome
# ..                                                ...
# 95  https://github.com/collectiveidea/acts_as_geoc...
# 96    https://github.com/collectiveidea/acts_as_money
# 97  https://github.com/collectiveidea/calendar_bui...
# 98  https://github.com/collectiveidea/clear_empty_...
# 99    https://github.com/collectiveidea/css_naked_day
#
#                                           description   fork  \
# 0   **Grit is no longer maintained. Check out libg...  False
# 1            Merb Core: All you need. None you don't.  False
# 2                      The Rubinius Language Platform  False
# 3                                Ruby process monitor  False
# 4                                        Awesome JSON  False
# ..                                                ...    ...
# 95          Simple geocoding for Active Record models  False
# 96  an Active Record plugin that makes it easier t...  False
# 97                                               None  False
# 98  When Active Record objects are saved from a fo...  False
# 99  A Rails plugin that disables all CSS on CSS Na...  False
#
#                                                   url  ...  \
# 0           https://api.github.com/repos/mojombo/grit  ...
# 1       https://api.github.com/repos/wycats/merb-core  ...
# 2      https://api.github.com/repos/rubinius/rubinius  ...
# 3            https://api.github.com/repos/mojombo/god  ...
# 4      https://api.github.com/repos/vanpelt/jsawesome  ...
# ..                                                ...  ...
# 95  https://api.github.com/repos/collectiveidea/ac...  ...
# 96  https://api.github.com/repos/collectiveidea/ac...  ...
# 97  https://api.github.com/repos/collectiveidea/ca...  ...
# 98  https://api.github.com/repos/collectiveidea/cl...  ...
# 99  https://api.github.com/repos/collectiveidea/cs...  ...
#
#                                            merges_url  \
# 0    https://api.github.com/repos/mojombo/grit/merges
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3     https://api.github.com/repos/mojombo/god/merges
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                           archive_url  \
# 0   https://api.github.com/repos/mojombo/grit/{arc...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/{arch...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                         downloads_url  \
# 0   https://api.github.com/repos/mojombo/grit/down...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/downl...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                            issues_url  \
# 0   https://api.github.com/repos/mojombo/grit/issu...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/issue...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                             pulls_url  \
# 0   https://api.github.com/repos/mojombo/grit/pull...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/pulls...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                        milestones_url  \
# 0   https://api.github.com/repos/mojombo/grit/mile...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/miles...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                     notifications_url  \
# 0   https://api.github.com/repos/mojombo/grit/noti...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/notif...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                            labels_url  \
# 0   https://api.github.com/repos/mojombo/grit/labe...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/label...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                          releases_url  \
# 0   https://api.github.com/repos/mojombo/grit/rele...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/relea...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                       deployments_url
# 0   https://api.github.com/repos/mojombo/grit/depl...
# 1   https://api.github.com/repos/wycats/merb-core/...
# 2   https://api.github.com/repos/rubinius/rubinius...
# 3   https://api.github.com/repos/mojombo/god/deplo...
# 4   https://api.github.com/repos/vanpelt/jsawesome...
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
# [100 rows x 46 columns]

# %%
repos_df = pd.json_normalize(payload)

# %%
repos_df
# Out:
#      id                   node_id                    name  \
# 0     1      MDEwOlJlcG9zaXRvcnkx                    grit
# 1    26  MDEwOlJlcG9zaXRvcnkyNg==               merb-core
# 2    27  MDEwOlJlcG9zaXRvcnkyNw==                rubinius
# 3    28  MDEwOlJlcG9zaXRvcnkyOA==                     god
# 4    29  MDEwOlJlcG9zaXRvcnkyOQ==               jsawesome
# ..  ...                       ...                     ...
# 95  364  MDEwOlJlcG9zaXRvcnkzNjQ=      acts_as_geocodable
# 96  365  MDEwOlJlcG9zaXRvcnkzNjU=           acts_as_money
# 97  367  MDEwOlJlcG9zaXRvcnkzNjc=        calendar_builder
# 98  368  MDEwOlJlcG9zaXRvcnkzNjg=  clear_empty_attributes
# 99  369  MDEwOlJlcG9zaXRvcnkzNjk=           css_naked_day
#
#                                 full_name  private  \
# 0                            mojombo/grit    False
# 1                        wycats/merb-core    False
# 2                       rubinius/rubinius    False
# 3                             mojombo/god    False
# 4                       vanpelt/jsawesome    False
# ..                                    ...      ...
# 95      collectiveidea/acts_as_geocodable    False
# 96           collectiveidea/acts_as_money    False
# 97        collectiveidea/calendar_builder    False
# 98  collectiveidea/clear_empty_attributes    False
# 99           collectiveidea/css_naked_day    False
#
#                                              html_url  \
# 0                     https://github.com/mojombo/grit
# 1                 https://github.com/wycats/merb-core
# 2                https://github.com/rubinius/rubinius
# 3                      https://github.com/mojombo/god
# 4                https://github.com/vanpelt/jsawesome
# ..                                                ...
# 95  https://github.com/collectiveidea/acts_as_geoc...
# 96    https://github.com/collectiveidea/acts_as_money
# 97  https://github.com/collectiveidea/calendar_bui...
# 98  https://github.com/collectiveidea/clear_empty_...
# 99    https://github.com/collectiveidea/css_naked_day
#
#                                           description   fork  \
# 0   **Grit is no longer maintained. Check out libg...  False
# 1            Merb Core: All you need. None you don't.  False
# 2                      The Rubinius Language Platform  False
# 3                                Ruby process monitor  False
# 4                                        Awesome JSON  False
# ..                                                ...    ...
# 95          Simple geocoding for Active Record models  False
# 96  an Active Record plugin that makes it easier t...  False
# 97                                               None  False
# 98  When Active Record objects are saved from a fo...  False
# 99  A Rails plugin that disables all CSS on CSS Na...  False
#
#                                                   url  \
# 0           https://api.github.com/repos/mojombo/grit
# 1       https://api.github.com/repos/wycats/merb-core
# 2      https://api.github.com/repos/rubinius/rubinius
# 3            https://api.github.com/repos/mojombo/god
# 4      https://api.github.com/repos/vanpelt/jsawesome
# ..                                                ...
# 95  https://api.github.com/repos/collectiveidea/ac...
# 96  https://api.github.com/repos/collectiveidea/ac...
# 97  https://api.github.com/repos/collectiveidea/ca...
# 98  https://api.github.com/repos/collectiveidea/cl...
# 99  https://api.github.com/repos/collectiveidea/cs...
#
#                                             forks_url  ...  \
# 0     https://api.github.com/repos/mojombo/grit/forks  ...
# 1   https://api.github.com/repos/wycats/merb-core/...  ...
# 2   https://api.github.com/repos/rubinius/rubinius...  ...
# 3      https://api.github.com/repos/mojombo/god/forks  ...
# 4   https://api.github.com/repos/vanpelt/jsawesome...  ...
# ..                                                ...  ...
# 95  https://api.github.com/repos/collectiveidea/ac...  ...
# 96  https://api.github.com/repos/collectiveidea/ac...  ...
# 97  https://api.github.com/repos/collectiveidea/ca...  ...
# 98  https://api.github.com/repos/collectiveidea/cl...  ...
# 99  https://api.github.com/repos/collectiveidea/cs...  ...
#
#                                   owner.following_url  \
# 0   https://api.github.com/users/mojombo/following...
# 1   https://api.github.com/users/wycats/following{...
# 2   https://api.github.com/users/rubinius/followin...
# 3   https://api.github.com/users/mojombo/following...
# 4   https://api.github.com/users/vanpelt/following...
# ..                                                ...
# 95  https://api.github.com/users/collectiveidea/fo...
# 96  https://api.github.com/users/collectiveidea/fo...
# 97  https://api.github.com/users/collectiveidea/fo...
# 98  https://api.github.com/users/collectiveidea/fo...
# 99  https://api.github.com/users/collectiveidea/fo...
#
#                                       owner.gists_url  \
# 0   https://api.github.com/users/mojombo/gists{/gi...
# 1   https://api.github.com/users/wycats/gists{/gis...
# 2   https://api.github.com/users/rubinius/gists{/g...
# 3   https://api.github.com/users/mojombo/gists{/gi...
# 4   https://api.github.com/users/vanpelt/gists{/gi...
# ..                                                ...
# 95  https://api.github.com/users/collectiveidea/gi...
# 96  https://api.github.com/users/collectiveidea/gi...
# 97  https://api.github.com/users/collectiveidea/gi...
# 98  https://api.github.com/users/collectiveidea/gi...
# 99  https://api.github.com/users/collectiveidea/gi...
#
#                                     owner.starred_url  \
# 0   https://api.github.com/users/mojombo/starred{/...
# 1   https://api.github.com/users/wycats/starred{/o...
# 2   https://api.github.com/users/rubinius/starred{...
# 3   https://api.github.com/users/mojombo/starred{/...
# 4   https://api.github.com/users/vanpelt/starred{/...
# ..                                                ...
# 95  https://api.github.com/users/collectiveidea/st...
# 96  https://api.github.com/users/collectiveidea/st...
# 97  https://api.github.com/users/collectiveidea/st...
# 98  https://api.github.com/users/collectiveidea/st...
# 99  https://api.github.com/users/collectiveidea/st...
#
#                               owner.subscriptions_url  \
# 0   https://api.github.com/users/mojombo/subscript...
# 1   https://api.github.com/users/wycats/subscriptions
# 2   https://api.github.com/users/rubinius/subscrip...
# 3   https://api.github.com/users/mojombo/subscript...
# 4   https://api.github.com/users/vanpelt/subscript...
# ..                                                ...
# 95  https://api.github.com/users/collectiveidea/su...
# 96  https://api.github.com/users/collectiveidea/su...
# 97  https://api.github.com/users/collectiveidea/su...
# 98  https://api.github.com/users/collectiveidea/su...
# 99  https://api.github.com/users/collectiveidea/su...
#
#                              owner.organizations_url  \
# 0          https://api.github.com/users/mojombo/orgs
# 1           https://api.github.com/users/wycats/orgs
# 2         https://api.github.com/users/rubinius/orgs
# 3          https://api.github.com/users/mojombo/orgs
# 4          https://api.github.com/users/vanpelt/orgs
# ..                                               ...
# 95  https://api.github.com/users/collectiveidea/orgs
# 96  https://api.github.com/users/collectiveidea/orgs
# 97  https://api.github.com/users/collectiveidea/orgs
# 98  https://api.github.com/users/collectiveidea/orgs
# 99  https://api.github.com/users/collectiveidea/orgs
#
#                                       owner.repos_url  \
# 0          https://api.github.com/users/mojombo/repos
# 1           https://api.github.com/users/wycats/repos
# 2         https://api.github.com/users/rubinius/repos
# 3          https://api.github.com/users/mojombo/repos
# 4          https://api.github.com/users/vanpelt/repos
# ..                                                ...
# 95  https://api.github.com/users/collectiveidea/repos
# 96  https://api.github.com/users/collectiveidea/repos
# 97  https://api.github.com/users/collectiveidea/repos
# 98  https://api.github.com/users/collectiveidea/repos
# 99  https://api.github.com/users/collectiveidea/repos
#
#                                      owner.events_url  \
# 0   https://api.github.com/users/mojombo/events{/p...
# 1   https://api.github.com/users/wycats/events{/pr...
# 2   https://api.github.com/users/rubinius/events{/...
# 3   https://api.github.com/users/mojombo/events{/p...
# 4   https://api.github.com/users/vanpelt/events{/p...
# ..                                                ...
# 95  https://api.github.com/users/collectiveidea/ev...
# 96  https://api.github.com/users/collectiveidea/ev...
# 97  https://api.github.com/users/collectiveidea/ev...
# 98  https://api.github.com/users/collectiveidea/ev...
# 99  https://api.github.com/users/collectiveidea/ev...
#
#                             owner.received_events_url    owner.type  \
# 0   https://api.github.com/users/mojombo/received_...          User
# 1   https://api.github.com/users/wycats/received_e...          User
# 2   https://api.github.com/users/rubinius/received...  Organization
# 3   https://api.github.com/users/mojombo/received_...          User
# 4   https://api.github.com/users/vanpelt/received_...          User
# ..                                                ...           ...
# 95  https://api.github.com/users/collectiveidea/re...  Organization
# 96  https://api.github.com/users/collectiveidea/re...  Organization
# 97  https://api.github.com/users/collectiveidea/re...  Organization
# 98  https://api.github.com/users/collectiveidea/re...  Organization
# 99  https://api.github.com/users/collectiveidea/re...  Organization
#
#    owner.site_admin
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 95            False
# 96            False
# 97            False
# 98            False
# 99            False
#
# [100 rows x 63 columns]

# %%
repos_df.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'owner.login', 'owner.id', 'owner.node_id',
#        'owner.avatar_url', 'owner.gravatar_id', 'owner.url', 'owner.html_url',
#        'owner.followers_url', 'owner.following_url', 'owner.gists_url',
#        'owner.starred_url', 'owner.subscriptions_url',
#        'owner.organizations_url', 'owner.repos_url', 'owner.events_url',
#        'owner.received_events_url', 'owner.type', 'owner.site_admin'],
#       dtype='object')

# %%
repos_df.dtypes
# Out:
# id                            int64
# node_id                      object
# name                         object
# full_name                    object
# private                        bool
#                               ...
# owner.repos_url              object
# owner.events_url             object
# owner.received_events_url    object
# owner.type                   object
# owner.site_admin               bool
# Length: 63, dtype: object

# %%
repos_df.shape
# Out:
# (100, 63)

# %%
repos_df.count()
# Out:
# id                           100
# node_id                      100
# name                         100
# full_name                    100
# private                      100
#                             ...
# owner.repos_url              100
# owner.events_url             100
# owner.received_events_url    100
# owner.type                   100
# owner.site_admin             100
# Length: 63, dtype: int64

# %% [markdown]
# Here are some of the tasks you can work on using `repos_df` data. We will explore the solutions using Pandas APIs.

# %%
since = 369

# %%
repos = requests.get(f'https://api.github.com/repositories?since={since}').json()

# %%
repos_df = pd.json_normalize(repos)

# %%
repos_df
# Out:
#      id                   node_id                  name  \
# 0   370  MDEwOlJlcG9zaXRvcnkzNzA=  imap_authenticatable
# 1   371  MDEwOlJlcG9zaXRvcnkzNzE=        random_finders
# 2   372  MDEwOlJlcG9zaXRvcnkzNzI=           with_action
# 3   374  MDEwOlJlcG9zaXRvcnkzNzQ=             graticule
# 4   376  MDEwOlJlcG9zaXRvcnkzNzY=                tinder
# ..  ...                       ...                   ...
# 95  856  MDEwOlJlcG9zaXRvcnk4NTY=                gemify
# 96  866  MDEwOlJlcG9zaXRvcnk4NjY=                  mor7
# 97  867  MDEwOlJlcG9zaXRvcnk4Njc=                  blog
# 98  872  MDEwOlJlcG9zaXRvcnk4NzI=              hairball
# 99  876  MDEwOlJlcG9zaXRvcnk4NzY=             merb-core
#
#                               full_name  private  \
# 0   collectiveidea/imap_authenticatable    False
# 1         collectiveidea/random_finders    False
# 2            collectiveidea/with_action    False
# 3              collectiveidea/graticule    False
# 4                 collectiveidea/tinder    False
# ..                                  ...      ...
# 95                       judofyr/gemify    False
# 96                     macournoyer/mor7    False
# 97                       jredville/blog    False
# 98                   ericallam/hairball    False
# 99                jackdempsey/merb-core    False
#
#                                              html_url  \
# 0   https://github.com/collectiveidea/imap_authent...
# 1    https://github.com/collectiveidea/random_finders
# 2       https://github.com/collectiveidea/with_action
# 3         https://github.com/collectiveidea/graticule
# 4            https://github.com/collectiveidea/tinder
# ..                                                ...
# 95                  https://github.com/judofyr/gemify
# 96                https://github.com/macournoyer/mor7
# 97                  https://github.com/jredville/blog
# 98              https://github.com/ericallam/hairball
# 99           https://github.com/jackdempsey/merb-core
#
#                                           description   fork  \
# 0   Authenticate your Rails app using any IMAP ser...  False
# 1   A Rails plugin that allows quick and easy fetc...  False
# 2   A respond_to style helper for doing different ...  False
# 3   Graticule is a geocoding API for looking up ad...  False
# 4   Tinder is a Ruby API for interfacing with Camp...  False
# ..                                                ...    ...
# 95                    The lightweight gemspec editor.  False
# 96        My Montreal on Rails 7 presentation of Thin  False
# 97                                 Personal blog code  False
# 98  A Haml clone built using the Treetop parser ge...  False
# 99           Merb Core: All you need. None you don't.   True
#
#                                                   url  \
# 0   https://api.github.com/repos/collectiveidea/im...
# 1   https://api.github.com/repos/collectiveidea/ra...
# 2   https://api.github.com/repos/collectiveidea/wi...
# 3   https://api.github.com/repos/collectiveidea/gr...
# 4   https://api.github.com/repos/collectiveidea/ti...
# ..                                                ...
# 95        https://api.github.com/repos/judofyr/gemify
# 96      https://api.github.com/repos/macournoyer/mor7
# 97        https://api.github.com/repos/jredville/blog
# 98    https://api.github.com/repos/ericallam/hairball
# 99  https://api.github.com/repos/jackdempsey/merb-...
#
#                                             forks_url  ...  \
# 0   https://api.github.com/repos/collectiveidea/im...  ...
# 1   https://api.github.com/repos/collectiveidea/ra...  ...
# 2   https://api.github.com/repos/collectiveidea/wi...  ...
# 3   https://api.github.com/repos/collectiveidea/gr...  ...
# 4   https://api.github.com/repos/collectiveidea/ti...  ...
# ..                                                ...  ...
# 95  https://api.github.com/repos/judofyr/gemify/forks  ...
# 96  https://api.github.com/repos/macournoyer/mor7/...  ...
# 97  https://api.github.com/repos/jredville/blog/forks  ...
# 98  https://api.github.com/repos/ericallam/hairbal...  ...
# 99  https://api.github.com/repos/jackdempsey/merb-...  ...
#
#                                   owner.following_url  \
# 0   https://api.github.com/users/collectiveidea/fo...
# 1   https://api.github.com/users/collectiveidea/fo...
# 2   https://api.github.com/users/collectiveidea/fo...
# 3   https://api.github.com/users/collectiveidea/fo...
# 4   https://api.github.com/users/collectiveidea/fo...
# ..                                                ...
# 95  https://api.github.com/users/judofyr/following...
# 96  https://api.github.com/users/macournoyer/follo...
# 97  https://api.github.com/users/jredville/followi...
# 98  https://api.github.com/users/ericallam/followi...
# 99  https://api.github.com/users/jackdempsey/follo...
#
#                                       owner.gists_url  \
# 0   https://api.github.com/users/collectiveidea/gi...
# 1   https://api.github.com/users/collectiveidea/gi...
# 2   https://api.github.com/users/collectiveidea/gi...
# 3   https://api.github.com/users/collectiveidea/gi...
# 4   https://api.github.com/users/collectiveidea/gi...
# ..                                                ...
# 95  https://api.github.com/users/judofyr/gists{/gi...
# 96  https://api.github.com/users/macournoyer/gists...
# 97  https://api.github.com/users/jredville/gists{/...
# 98  https://api.github.com/users/ericallam/gists{/...
# 99  https://api.github.com/users/jackdempsey/gists...
#
#                                     owner.starred_url  \
# 0   https://api.github.com/users/collectiveidea/st...
# 1   https://api.github.com/users/collectiveidea/st...
# 2   https://api.github.com/users/collectiveidea/st...
# 3   https://api.github.com/users/collectiveidea/st...
# 4   https://api.github.com/users/collectiveidea/st...
# ..                                                ...
# 95  https://api.github.com/users/judofyr/starred{/...
# 96  https://api.github.com/users/macournoyer/starr...
# 97  https://api.github.com/users/jredville/starred...
# 98  https://api.github.com/users/ericallam/starred...
# 99  https://api.github.com/users/jackdempsey/starr...
#
#                               owner.subscriptions_url  \
# 0   https://api.github.com/users/collectiveidea/su...
# 1   https://api.github.com/users/collectiveidea/su...
# 2   https://api.github.com/users/collectiveidea/su...
# 3   https://api.github.com/users/collectiveidea/su...
# 4   https://api.github.com/users/collectiveidea/su...
# ..                                                ...
# 95  https://api.github.com/users/judofyr/subscript...
# 96  https://api.github.com/users/macournoyer/subsc...
# 97  https://api.github.com/users/jredville/subscri...
# 98  https://api.github.com/users/ericallam/subscri...
# 99  https://api.github.com/users/jackdempsey/subsc...
#
#                              owner.organizations_url  \
# 0   https://api.github.com/users/collectiveidea/orgs
# 1   https://api.github.com/users/collectiveidea/orgs
# 2   https://api.github.com/users/collectiveidea/orgs
# 3   https://api.github.com/users/collectiveidea/orgs
# 4   https://api.github.com/users/collectiveidea/orgs
# ..                                               ...
# 95         https://api.github.com/users/judofyr/orgs
# 96     https://api.github.com/users/macournoyer/orgs
# 97       https://api.github.com/users/jredville/orgs
# 98       https://api.github.com/users/ericallam/orgs
# 99     https://api.github.com/users/jackdempsey/orgs
#
#                                       owner.repos_url  \
# 0   https://api.github.com/users/collectiveidea/repos
# 1   https://api.github.com/users/collectiveidea/repos
# 2   https://api.github.com/users/collectiveidea/repos
# 3   https://api.github.com/users/collectiveidea/repos
# 4   https://api.github.com/users/collectiveidea/repos
# ..                                                ...
# 95         https://api.github.com/users/judofyr/repos
# 96     https://api.github.com/users/macournoyer/repos
# 97       https://api.github.com/users/jredville/repos
# 98       https://api.github.com/users/ericallam/repos
# 99     https://api.github.com/users/jackdempsey/repos
#
#                                      owner.events_url  \
# 0   https://api.github.com/users/collectiveidea/ev...
# 1   https://api.github.com/users/collectiveidea/ev...
# 2   https://api.github.com/users/collectiveidea/ev...
# 3   https://api.github.com/users/collectiveidea/ev...
# 4   https://api.github.com/users/collectiveidea/ev...
# ..                                                ...
# 95  https://api.github.com/users/judofyr/events{/p...
# 96  https://api.github.com/users/macournoyer/event...
# 97  https://api.github.com/users/jredville/events{...
# 98  https://api.github.com/users/ericallam/events{...
# 99  https://api.github.com/users/jackdempsey/event...
#
#                             owner.received_events_url    owner.type  \
# 0   https://api.github.com/users/collectiveidea/re...  Organization
# 1   https://api.github.com/users/collectiveidea/re...  Organization
# 2   https://api.github.com/users/collectiveidea/re...  Organization
# 3   https://api.github.com/users/collectiveidea/re...  Organization
# 4   https://api.github.com/users/collectiveidea/re...  Organization
# ..                                                ...           ...
# 95  https://api.github.com/users/judofyr/received_...          User
# 96  https://api.github.com/users/macournoyer/recei...          User
# 97  https://api.github.com/users/jredville/receive...          User
# 98  https://api.github.com/users/ericallam/receive...          User
# 99  https://api.github.com/users/jackdempsey/recei...          User
#
#    owner.site_admin
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 95            False
# 96            False
# 97            False
# 98            False
# 99            False
#
# [100 rows x 63 columns]

# %% [markdown]
# * Get number of repositories.

# %%
repos_df.shape
# Out:
# (100, 63)

# %%
repos_df.shape[0]
# Out:
# 100

# %% [markdown]
# * Get repository name, url and owner type of all repositories.

# %%
repos_df

# %%
repos_df[['name', 'url', 'owner.type']]

# %% [markdown]
# * Get all unique or distinct owner types of the repositories. The output should be of type **list**.

# %%
repos_df['owner.type']

# %%
repos_df['owner.type'].unique()

# %%
list(repos_df['owner.type'].unique())

# %% [markdown]
# * Get number of repositories where owner type is **User**.

# %%
repos_df['owner.type'] == 'User'

# %%
repos_df[repos_df['owner.type'] == 'User']

# %%
repos_df[repos_df['owner.type'] == 'User'].shape

# %%
repos_df[repos_df['owner.type'] == 'User'].shape[0]

# %% [markdown]
# * Get number of repositories where owner type is **Organization**.

# %%
repos_df[repos_df['owner.type'] == 'Organization'].shape[0]

# %% [markdown]
# * Get number of repositories by each owner type.

# %%
repos_df.groupby('owner.type')

# %%
repos_df.groupby('owner.type')['owner.type'].count()
# Out:
# owner.type
# Organization     7
# User            93
# Name: owner.type, dtype: int64

# %% [markdown]
# * Sort the data by owner type and then by id. Ensure that data is sorted by id as numeric.

# %%
repos_df.dtypes

# %%
repos_df.sort_values(by=['owner.type', 'id']).head(10)
