# %%
# %run 04_function_get_database_connection.ipynb

# %%
import pandas as pd

yt_video_data = pd.read_csv('Backup_UCakdSIPsJqiOLqylgoYmwQg_1_of_1.csv')

# %%
yt_video_data
# Out:
#          Video Id                Channel Id  \
# 0     ad-GXe5J9RE  UCakdSIPsJqiOLqylgoYmwQg
# 1     pxwPEnLsKvU  UCakdSIPsJqiOLqylgoYmwQg
# 2     EVp-skflxO4  UCakdSIPsJqiOLqylgoYmwQg
# 3     -XmkPihHHhA  UCakdSIPsJqiOLqylgoYmwQg
# 4     fZ-QOUk-ia4  UCakdSIPsJqiOLqylgoYmwQg
# ...           ...                       ...
# 3250  qxUw2BbnTNk  UCakdSIPsJqiOLqylgoYmwQg
# 3251  VQVcS3qES98  UCakdSIPsJqiOLqylgoYmwQg
# 3252  nY_fnlmPeuM  UCakdSIPsJqiOLqylgoYmwQg
# 3253  HaU43H_HlqM  UCakdSIPsJqiOLqylgoYmwQg
# 3254  1lozVbGla5Q  UCakdSIPsJqiOLqylgoYmwQg
#
#                                                   Title  \
# 0     Mastering Python - Overview of Collections - d...
# 1     Mastering Python - Overview of Collections - d...
# 2     Mastering Python - Overview of Collections - d...
# 3     Mastering Python - Overview of Collections - d...
# 4     Mastering Python - Overview of Collections - d...
# ...                                                 ...
# 3250  Data Analytics using Hadoop - 01 Understanding...
# 3251  Oozie and demostrating EDW demo using Hadoop e...
# 3252                                BigDataIntroduction
# 3253  Amazon Web Services - Install Cloudera Distrib...
# 3254      Amazon Web Services - Elastic Cloud Computing
#
#                                                    Tags  \
# 0     comprehensive python workshop,python lambda fu...
# 1     python for freshers,python collections,python ...
# 2     python for beginners,python tutorial,python wo...
# 3     python using jupyter notebook,python workshop,...
# 4     python using jupyter notebook,comprehensive py...
# ...                                                 ...
# 3250  Apache Hadoop (Software),Apache Hue,Apache Hiv...
# 3251  Apache Pig,Apache Hive,Apache Hadoop,Enterpris...
# 3252                                                NaN
# 3253  Amazon Web Services (Website),Apache Hadoop (S...
# 3254  Cloud Computing (Industry),Amazon.com (Venture...
#
#                                             Description  Privacy  \
# 0     Feel free to access the complete material from...   Public
# 1     Feel free to access the complete material from...   Public
# 2     Feel free to access the complete material from...   Public
# 3     Feel free to access the complete material from...   Public
# 4     Feel free to access the complete material from...   Public
# ...                                                 ...      ...
# 3250  Connect with me or follow me at\nhttps://www.l...   Public
# 3251  If you need material and data, please connect ...   Public
# 3252  Compare and contrast conventional against big ...  Private
# 3253  Connect with me or follow me at\nhttps://www.l...   Public
# 3254  Connect with me or follow me at\nhttps://www.l...   Public
#
#       Date Published   Category Id         Category Name  \
# 0         2020-12-23            27             Education
# 1         2020-12-23            27             Education
# 2         2020-12-23            27             Education
# 3         2020-12-23            27             Education
# 4         2020-12-23            27             Education
# ...              ...           ...                   ...
query = ("""
INSERT INTO videos (
    video_id, video_title, video_description, 
    video_category_name, video_file_name,
    video_privacy_status, video_published_dt
)
VALUES
    (%s, %s, %s, %s, %s, %s, %s)
""")

# %%
def load_data(connection, cursor, query, data):
    cursor.executemany(query, data)
    connection.commit()

# %%
yt_video_data.columns
# Out:
# Index(['Video Id', ' Channel Id', ' Title', ' Tags', ' Description',
#        ' Privacy', ' Date Published', ' Category Id', ' Category Name',
#        ' Thumbnail Url', ' Watch Url', ' FileName', ' Date Backed Up',
#        ' View Count', ' Comment Count', ' Like Count', ' Dislike Count',
#        ' Length (seconds)'],
#       dtype='object')

# %%
yt_video_data = yt_video_data[[
    'Video Id', ' Title', ' Description', ' Category Name',
    ' FileName', ' Privacy', ' Date Published'
]]

# %%
load_data(
    yt_connection, yt_connection.cursor(), 
    query, yt_video_data.values.tolist()
)

# %%
yt_connection.commit()

# %%
yt_video_data.dtypes
# Out:
# Video Id             object
#  Channel Id          object
#  Title               object
#  Tags                object
#  Description         object
#  Privacy             object
#  Date Published      object
#  Category Id          int64
#  Category Name       object
#  Thumbnail Url       object
#  Watch Url           object
#  FileName            object
#  Date Backed Up      object
#  View Count           int64
#  Comment Count        int64
#  Like Count           int64
#  Dislike Count        int64
#  Length (seconds)     int64
# dtype: object

# %%
# %load_ext sql

# %%
# %run 01_setup_database.ipynb

# %%
# %%sql
#
# SELECT * FROM videos LIMIT 10
# Out:
# 10 rows affected.
# [('ad-GXe5J9RE', 'Mastering Python - Overview of Collections - dict and tuple - 08 List of Tuples', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '08 List of Tuples.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('pxwPEnLsKvU', 'Mastering Python - Overview of Collections - dict and tuple - 09 List of dicts', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '09 List of dicts.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('EVp-skflxO4', 'Mastering Python - Overview of Collections - dict and tuple - 06 Manipulating dict', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '06 Manipulating dict.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('-XmkPihHHhA', 'Mastering Python - Overview of Collections - dict and tuple - 07 Common Examples   dict', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '07 Common Examples - dict.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('fZ-QOUk-ia4', 'Mastering Python - Overview of Collections - dict and tuple - 05 Accessing Elements   tuples', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '05 Accessing Elements - tuples.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('FpxL1G8ktOk', 'Mastering Python - Overview of Collections - dict and tuple - 04 Accessing Elements   dict', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '04 Accessing Elements - dict.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('Cc_zWN2u6F8', 'Mastering Python - Overview of Collections - dict and tuple - 03 Common Operations   dict and tuple', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '03 Common Operations - dict and tuple.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('G79XqjTXm74', 'Mastering Python - Overview of Collections - dict and tuple - 02 Overview of dict and tuple', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner.\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Education', '02 Overview of dict and tuple.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('-7fS4iSiAAU', 'Mastering Python - Overview of Collections - list and set - 06 Updating and Deleting elements   list', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner. \n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Science & Technology', '06 Updating and Deleting elements - list.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4)),
#  ('4hiDOB-qJ1U', 'Mastering Python - Overview of Collections - list and set - 02 Overview of list and set', 'Feel free to access the complete material from https://python.itversity.com. You can also download each notebook from top right corner. \n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCakdSIPsJqiOLqylgoYmwQg/join', 'Science & Technology', '02 Overview of list and set.mp4', 'Public', datetime.date(2020, 12, 23), datetime.date(2021, 1, 4))]

# %%
# %%sql
#
# SELECT video_category_name, count(1)
# FROM videos
# GROUP BY video_category_name
# Out:
#  * postgresql://yt_user:***@localhost:5432/yt_db
# 2 rows affected.
# [('Education', 8), ('Science & Technology', 3247)]

# %%
# %%sql
#
# SELECT video_privacy_status, count(1)
# FROM videos
# GROUP BY video_privacy_status
# Out:
#  * postgresql://yt_user:***@localhost:5432/yt_db
# 3 rows affected.
# [('Private', 20), ('Unlisted', 279), ('Public', 2956)]

# %%
# %run 03_configure_youtube_apis.ipynb
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=684254837377-fgfrvlp2d6sml1975u58c9q6osj79tkt.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube&state=l0pyoCqNOs6GIiaHfhlvFime0TtJgR&prompt=consent&access_type=offline
# Enter the authorization code:  4/1AY0e-g5bOfN27arg7P3cXecPYVxILuHzUdkP94bygVWIZ0H1lKfhn4mALt4

# %%
youtube

# %%
# Don't run this search query
# It costs 100 units
# videos = youtube.search().list(
#     part='snippet',
#     channelId='UCakdSIPsJqiOLqylgoYmwQg',
#     maxResults=50
# ).execute()

# %%
# videos

# %%
len(videos['items'])

# %%
videos['items'][0]['id']

# %%
nextPageToken = None
video_ids = []
while True:
    videos = youtube.search().list(
        part = 'snippet',
        channelId='UCakdSIPsJqiOLqylgoYmwQg',
        pageToken = nextPageToken,
        maxResults = 50
    ).execute()

    for item in videos['items']:
        if item['id']['kind'] == 'youtube#video':
            video_ids.append(
                (
                    item['id']['videoId']
                )
            )

    nextPageToken = videos.get('nextPageToken')
    if not nextPageToken:
        break

# %%
nextPageToken = None
playlist_details = []
while True:
    playlists = youtube.playlists().list(
        part = 'snippet,contentDetails,status',
        channelId='UCakdSIPsJqiOLqylgoYmwQg',
        pageToken = nextPageToken,
        maxResults = 50
    ).execute()

    for item in playlists['items']:
        playlist_details.append(
            (
                item['id'], item['snippet']['title'], item['snippet']['description'],
                item['contentDetails']['itemCount'], item['status']['privacyStatus']
            )
        )

    nextPageToken = playlists.get('nextPageToken')
    if not nextPageToken:
        break

# %%
len(playlist_details)

# %%
playlist_details[0]

# %%
def get_playlists(youtube, channel):
    nextPageToken = None
    playlists_details = []
    
    while True:
        playlists = youtube.playlists().list(
            part = 'snippet,contentDetails,status',
            channelId=channel,
            pageToken = nextPageToken,
            maxResults = 50
        ).execute()

        for item in playlists['items']:
            playlists_details.append(
                (
                    item['id'], item['snippet']['title'], item['snippet']['description'],
                    item['contentDetails']['itemCount'], item['status']['privacyStatus']
                )
            )

        nextPageToken = playlists.get('nextPageToken')
        if not nextPageToken:
            break

    return playlists_details

# %%
def get_playlist_items(playlistId):
    nextPageToken = None
    video_ids = []
    while True:
        playlistItems = youtube.playlistItems().list(
            part = 'contentDetails',
            playlistId = playlistId,
            pageToken = nextPageToken,
            maxResults = 50
        ).execute()
        
        video_ids += [item['contentDetails']['videoId'] for item in playlistItems['items']]
        
        nextPageToken = playlistItems.get('nextPageToken')
        if not nextPageToken:
            break
    return video_ids
